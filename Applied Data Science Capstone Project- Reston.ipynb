# %%
#This notebook will mainly be used for the capstone project.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
#Import Libraries
import requests
from bs4 import BeautifulSoup
import csv
import pandas as pd
import pandas as pd
import numpy as np
import requests

from bs4 import BeautifulSoup

import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
## URL to extract City neighbourhood information

df = pd.read_excel('NoVAdata.xlsx')

df.head()
# Out:
#           City   Latitude    Longitude  Population  Rent  CommuteMins
# 0    Chantilly  38.897980     -77.4387       24368  1600            2
# 1       Reston  38.944122     -77.3562       61147  1600           14
# 2      Herndon  38.969496     -77.3865       24532  1700           11
# 3  Centreville  38.840389     -77.4289       74125  1711            7
# 4      Fairfax  38.854004   -77.356918       23531  1400           19

# %%
df.shape
# Out:
# (7, 6)

# %%
address = 'Reston, VA'

geolocator = Nominatim(user_agent="va_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Reston, Virginia are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Reston, Virginia are 38.955696, -77.34188283719988.

# %%
# create map of Virginia using latitude and longitude values
map_va = folium.Map(location=[latitude, longitude], zoom_start=15)

map_va
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_3f468d25d20e411b9b18e94d335429d3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3f468d25d20e411b9b18e94d335429d3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3f468d25d20e411b9b18e94d335429d3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_3f468d25d20e411b9b18e94d335429d3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B38.955696%2C%20-77.34188283719988%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
# add markers to Virginia map

for lat, lng in zip(df['Latitude'], df['Longitude']):
    label = '{}, {}'.format(df)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='red',
        fill=True,
        #fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_va)  
    
map_va
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-30c7e8fba0f9> in <module>
#       1 # add markers to map
#       2 for lat, lng in zip(df['Latitude'], df['Longitude']):
# ----> 3     label = '{}, {}'.format(df)
#       4     label = folium.Popup(label, parse_html=True)
#       5     folium.CircleMarker(
#
# IndexError: Replacement index 1 out of range for positional args tuple

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in c:\users\t9465aa\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\t9465aa\anaconda3\lib\site-packages (from geopy) (1.52)
# Collecting folium==0.5.0
#   Downloading folium-0.5.0.tar.gz (79 kB)
# Requirement already satisfied: branca in c:\users\t9465aa\anaconda3\lib\site-packages (from folium==0.5.0) (0.4.2)
# Requirement already satisfied: jinja2 in c:\users\t9465aa\anaconda3\lib\site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: requests in c:\users\t9465aa\anaconda3\lib\site-packages (from folium==0.5.0) (2.24.0)
# Requirement already satisfied: six in c:\users\t9465aa\anaconda3\lib\site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\t9465aa\anaconda3\lib\site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\t9465aa\anaconda3\lib\site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\t9465aa\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\t9465aa\anaconda3\lib\site-packages (from requests->folium==0.5.0) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\t9465aa\anaconda3\lib\site-packages (from requests->folium==0.5.0) (2020.6.20)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py): started
#   Building wheel for folium (setup.py): finished with status 'done'
#   Created wheel for folium: filename=folium-0.5.0-py3-none-any.whl size=76256 sha256=2af771787091f6890755988dd1612a9b1fdf701e09223d2a0e1a36d383bf9565
#   Stored in directory: c:\users\t9465aa\appdata\local\pip\cache\wheels\ef\4c\4a\17fd3d7fb7b6243d5a7a8d165870cd5c6ad2ec4c0582f039e4
# Successfully built folium
# Installing collected packages: folium
#   Attempting uninstall: folium
#     Found existing installation: folium 0.12.1
#     Uninstalling folium-0.12.1:
#       Successfully uninstalled folium-0.12.1
# Successfully installed folium-0.5.0
# Folium installed
# Libraries imported.

# %%
#Foursquare

CLIENT_ID = 'FDITTVSJQZVB3D0CHDYHK1INFTXOR0UYZ51XAKUDW1IGQLV5' # your Foursquare ID
CLIENT_SECRET = '2JT5IL5I0DGROK14M3PWMBG54MRW5QSKTO4DJCOKJRYAWKJ3' # your Foursquare Secret
ACCESS_TOKEN = '05B50VTMVA2NKP0V52WT5LL5IEKEQVXQVLA1BZSRMWSH0UOP' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FDITTVSJQZVB3D0CHDYHK1INFTXOR0UYZ51XAKUDW1IGQLV5
# CLIENT_SECRET:2JT5IL5I0DGROK14M3PWMBG54MRW5QSKTO4DJCOKJRYAWKJ3

# %%
address = '11925 Bowman Towne Dr, Reston, VA'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.96146845 -77.3585048525

# %%
search_query = 'coffee'
radius = 500
print(search_query + ' .... OK!')
# Out:
# coffee .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&oauth_token={}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude,ACCESS_TOKEN, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=FDITTVSJQZVB3D0CHDYHK1INFTXOR0UYZ51XAKUDW1IGQLV5&client_secret=2JT5IL5I0DGROK14M3PWMBG54MRW5QSKTO4DJCOKJRYAWKJ3&ll=38.832106,-77.450555&oauth_token=05B50VTMVA2NKP0V52WT5LL5IEKEQVXQVLA1BZSRMWSH0UOP&v=20180604&query=coffee&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '610c3839fff1a46a215c49ba'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '500d3300e4b053e6587a09a4',
#     'name': 'break room 1-coffee station',
#     'location': {'lat': 38.96259307861328,
#      'lng': -77.35871124267578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.96259307861328,
#        'lng': -77.35871124267578}],
#      'distance': 126,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628190777',
#     'hasPerk': False},
#    {'id': '5cb4bdd72be425002cb66752',
#     'name': 'Peet’s Coffee By The Way.',
#     'location': {'address': '11830 Freedom Dr',
#      'lat': 38.9598274230957,
#      'lng': -77.35599517822266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9598274230957,
#        'lng': -77.35599517822266}],
#      'distance': 283,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11830 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628190777',
#     'hasPerk': False},
#    {'id': '526e97e5498e8f398b42840c',
#     'name': "Lentine's Coffee Shop",
#     'location': {'address': '1850 Town Center Pkwy',
#      'lat': 38.961887391253995,
#      'lng': -77.36428086195941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.961887391253995,
#        'lng': -77.36428086195941}],
#      'distance': 502,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1850 Town Center Pkwy', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628190777',
#     'hasPerk': False},
#    {'id': '4abcda37f964a520748720e3',
#     'name': 'Starbucks',
#     'location': {'address': '11951 Freedom Dr',
#      'crossStreet': 'at Market & Library St',
#      'lat': 38.95874830125791,
#      'lng': -77.35914829424134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95874830125791,
#        'lng': -77.35914829424134}],
#      'distance': 307,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11951 Freedom Dr (at Market & Library St)',
#       'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628190777',
#     'hasPerk': False},
#    {'id': '4ad3a23af964a52050e520e3',
#     'name': 'Starbucks',
#     'location': {'address': '1857 Fountain Dr',
#      'crossStreet': 'btwn New Dominion Pkwy & Bowman Towne Dr',
#      'lat': 38.96157566,
#      'lng': -77.35525428,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.96157566,
#        'lng': -77.35525428},
#       {'label': 'entrance', 'lat': 38.96156, 'lng': -77.355806}],
#      'distance': 281,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1857 Fountain Dr (btwn New Dominion Pkwy & Bowman Towne Dr)',
#       'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628190777',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-13-5acf500bf9ad>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id                         name  \
# 0  500d3300e4b053e6587a09a4  break room 1-coffee station
# 1  5cb4bdd72be425002cb66752    Peet’s Coffee By The Way.
# 2  526e97e5498e8f398b42840c        Lentine's Coffee Shop
# 3  4abcda37f964a520748720e3                    Starbucks
# 4  4ad3a23af964a52050e520e3                    Starbucks
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628190777    False
# 1  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628190777    False
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628190777    False
# 3  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628190777    False
# 4  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...  v-1628190777    False
#
#    location.lat  location.lng  \
# 0     38.962593    -77.358711
# 1     38.959827    -77.355995
# 2     38.961887    -77.364281
# 3     38.958748    -77.359148
# 4     38.961576    -77.355254
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 38.96259307861328...                126
# 1  [{'label': 'display', 'lat': 38.9598274230957,...                283
# 2  [{'label': 'display', 'lat': 38.96188739125399...                502
# 3  [{'label': 'display', 'lat': 38.95874830125791...                307
# 4  [{'label': 'display', 'lat': 38.96157566, 'lng...                281
#
#   location.postalCode location.cc location.city location.state  \
# 0               20190          US        Reston             VA
# 1               20190          US        Reston             VA
# 2               20190          US        Reston             VA
# 3               20190          US        Reston             VA
# 4               20190          US        Reston             VA
#
#   location.country                          location.formattedAddress  \
# 0    United States                                 [Reston, VA 20190]
# 1    United States               [11830 Freedom Dr, Reston, VA 20190]
# 2    United States          [1850 Town Center Pkwy, Reston, VA 20190]
# 3    United States  [11951 Freedom Dr (at Market & Library St), Re...
# 4    United States  [1857 Fountain Dr (btwn New Dominion Pkwy & Bo...
#
#         location.address                      location.crossStreet
# 0                    NaN                                       NaN
# 1       11830 Freedom Dr                                       NaN
# 2  1850 Town Center Pkwy                                       NaN
# 3       11951 Freedom Dr                    at Market & Library St
# 4       1857 Fountain Dr  btwn New Dominion Pkwy & Bowman Towne Dr

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                           name   categories        lat        lng  \
# 0  break room 1-coffee station  Coffee Shop  38.962593 -77.358711
# 1    Peet’s Coffee By The Way.  Coffee Shop  38.959827 -77.355995
# 2        Lentine's Coffee Shop  Coffee Shop  38.961887 -77.364281
# 3                    Starbucks  Coffee Shop  38.958748 -77.359148
# 4                    Starbucks  Coffee Shop  38.961576 -77.355254
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 38.96259307861328...       126      20190  US
# 1  [{'label': 'display', 'lat': 38.9598274230957,...       283      20190  US
# 2  [{'label': 'display', 'lat': 38.96188739125399...       502      20190  US
# 3  [{'label': 'display', 'lat': 38.95874830125791...       307      20190  US
# 4  [{'label': 'display', 'lat': 38.96157566, 'lng...       281      20190  US
#
#      city state        country  \
# 0  Reston    VA  United States
# 1  Reston    VA  United States
# 2  Reston    VA  United States
# 3  Reston    VA  United States
# 4  Reston    VA  United States
#
#                                     formattedAddress                address  \
# 0                                 [Reston, VA 20190]                    NaN
# 1               [11830 Freedom Dr, Reston, VA 20190]       11830 Freedom Dr
# 2          [1850 Town Center Pkwy, Reston, VA 20190]  1850 Town Center Pkwy
# 3  [11951 Freedom Dr (at Market & Library St), Re...       11951 Freedom Dr
# 4  [1857 Fountain Dr (btwn New Dominion Pkwy & Bo...       1857 Fountain Dr
#
#                                 crossStreet                        id
# 0                                       NaN  500d3300e4b053e6587a09a4
# 1                                       NaN  5cb4bdd72be425002cb66752
# 2                                       NaN  526e97e5498e8f398b42840c
# 3                    at Market & Library St  4abcda37f964a520748720e3
# 4  btwn New Dominion Pkwy & Bowman Towne Dr  4ad3a23af964a52050e520e3

# %%
dataframe_filtered.name
# Out:
# 0    break room 1-coffee station
# 1      Peet’s Coffee By The Way.
# 2          Lentine's Coffee Shop
# 3                      Starbucks
# 4                      Starbucks
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Reston Library

# add a red circle marker to represent the Library
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Library',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the coffee shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_0fbde067236c48169719d8e12b684c68%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0fbde067236c48169719d8e12b684c68%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0fbde067236c48169719d8e12b684c68%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_0fbde067236c48169719d8e12b684c68%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B38.96146845%2C-77.3585048525%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20% ...

# %%
search_query = 'gym'
radius = 500
print(search_query + ' .... OK!')
# Out:
# gym .... OK!

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '611139c83f0278275a378dd0'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': [{'id': '4d015a079fada35d4aa33c34',
#     'name': 'The Gym',
#     'location': {'address': '11937 Market St',
#      'lat': 38.958303,
#      'lng': -77.35781899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.958303,
#        'lng': -77.35781899999999},
#       {'label': 'entrance', 'lat': 38.958623, 'lng': -77.357518}],
#      'distance': 357,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11937 Market St', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '5092ea90e4b054dd33164e1c',
#     'name': 'One Freedom Gym',
#     'location': {'lat': 38.95916748046875,
#      'lng': -77.35944366455078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95916748046875,
#        'lng': -77.35944366455078}],
#      'distance': 268,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4d9335897ac3a35d6508d125',
#     'name': 'L3 Gym',
#     'location': {'address': '11955 Freedom Dr',
#      'lat': 38.95909881591797,
#      'lng': -77.3598861694336,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95909881591797,
#        'lng': -77.3598861694336}],
#      'distance': 289,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11955 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '5b85528ada5e560039bc3b15',
#     'name': 'The Gym Guides',
#     'location': {'address': '2143 Rhode Island Avenue',
#      'lat': 38.95765681368872,
#      'lng': -77.35755801200867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95765681368872,
#        'lng': -77.35755801200867}],
#      'distance': 432,
#      'postalCode': '22090',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'D.C.',
#      'country': 'United States',
#      'formattedAddress': ['2143 Rhode Island Avenue', 'Reston, D.C. 22090']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4fbbbedae4b05f98660d40fb',
#     'name': 'Gym 11951',
#     'location': {'address': '11951 Freedom Dr',
#      'lat': 38.958345321864044,
#      'lng': -77.35530923368962,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.958345321864044,
#        'lng': -77.35530923368962}],
#      'distance': 444,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11951 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4ca771d3f47ea14320be6a21',
#     'name': 'One Fountain Square Gym',
#     'location': {'address': '11911 Freedom Dr',
#      'lat': 38.95936384413637,
#      'lng': -77.3561164027195,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95936384413637,
#        'lng': -77.3561164027195}],
#      'distance': 312,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11911 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4e8b7cbad3e303e9db2bb950',
#     'name': 'RTC Gym',
#     'location': {'address': '11911 Freedom Dr',
#      'lat': 38.9591064453125,
#      'lng': -77.3561782836914,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9591064453125,
#        'lng': -77.3561782836914}],
#      'distance': 331,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11911 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4d262d8cb3ad60fc30793506',
#     'name': 'College Board Gym',
#     'location': {'address': '11955 Democracy Dr',
#      'crossStreet': '9th Floor',
#      'lat': 38.958259830902044,
#      'lng': -77.35994092331349,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.958259830902044,
#        'lng': -77.35994092331349}],
#      'distance': 378,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11955 Democracy Dr (9th Floor)',
#       'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4fc8af86e4b01d2b698624c3',
#     'name': 'Freedom Gym',
#     'location': {'lat': 38.9587931347436,
#      'lng': -77.35603259689839,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.9587931347436,
#        'lng': -77.35603259689839}],
#      'distance': 366,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '52ae37b811d2321247fd0427',
#     'name': 'Parc Reston Gym',
#     'location': {'lat': 38.96330012185097,
#      'lng': -77.35254471110908,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.96330012185097,
#        'lng': -77.35254471110908}],
#      'distance': 554,
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '50c7cdeae4b09076e37b9113',
#     'name': 'Archstone Gym',
#     'location': {'lat': 38.96664581743808,
#      'lng': -77.36101190515942,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.96664581743808,
#        'lng': -77.36101190515942}],
#      'distance': 615,
#      'postalCode': '20194',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA 20194']},
#     'categories': [{'id': '4f4528bc4b90abdf24c9de85',
#       'name': 'Athletics & Sports',
#       'pluralName': 'Athletics & Sports',
#       'shortName': 'Athletics & Sports',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4ac56d0bf964a520ffb120e3',
#     'name': 'Hyatt Regency Reston',
#     'location': {'address': '1800 Presidents St',
#      'lat': 38.95831095377073,
#      'lng': -77.35586437325652,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95831095377073,
#        'lng': -77.35586437325652}],
#      'distance': 419,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1800 Presidents St', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '51cdc1f5498eb301ccefd973',
#     'name': 'Crunch Fitness - Reston Town Center',
#     'location': {'address': '11951 Freedom Dr',
#      'lat': 38.95922209991875,
#      'lng': -77.35923305153847,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.95922209991875,
#        'lng': -77.35923305153847}],
#      'distance': 257,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['11951 Freedom Dr', 'Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d175941735',
#       'name': 'Gym / Fitness Center',
#       'pluralName': 'Gyms or Fitness Centers',
#       'shortName': 'Gym / Fitness',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '531984349'},
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '544ead43498e60f6ee26cff8',
#     'name': 'The Harrison',
#     'location': {'address': '1800 Jonathan Way',
#      'crossStreet': 'Reston Parkway',
#      'lat': 38.961845398198655,
#      'lng': -77.35404193535423,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.961845398198655,
#        'lng': -77.35404193535423}],
#      'distance': 388,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['1800 Jonathan Way (Reston Parkway)',
#       'Reston, VA 20190']},
#     'categories': [{'id': '4d954b06a243a5684965b473',
#       'name': 'Residential Building (Apartment / Condo)',
#       'pluralName': 'Residential Buildings (Apartments / Condos)',
#       'shortName': 'Residential',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/apartment_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False},
#    {'id': '4f05e27b5c5c4a361b035d64',
#     'name': 'Verisign Fitness Center',
#     'location': {'lat': 38.956753000000006,
#      'lng': -77.36225,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 38.956753000000006,
#        'lng': -77.36225}],
#      'distance': 616,
#      'postalCode': '20190',
#      'cc': 'US',
#      'city': 'Reston',
#      'state': 'VA',
#      'country': 'United States',
#      'formattedAddress': ['Reston, VA 20190']},
#     'categories': [{'id': '4bf58dd8d48988d176941735',
#       'name': 'Gym',
#       'pluralName': 'Gyms',
#       'shortName': 'Gym',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1628518856',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# <ipython-input-20-5acf500bf9ad>:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   dataframe = json_normalize(venues)
#                          id             name  \
# 0  4d015a079fada35d4aa33c34          The Gym
# 1  5092ea90e4b054dd33164e1c  One Freedom Gym
# 2  4d9335897ac3a35d6508d125           L3 Gym
# 3  5b85528ada5e560039bc3b15   The Gym Guides
# 4  4fbbbedae4b05f98660d40fb        Gym 11951
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1628518856    False
# 1  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1628518856    False
# 2  [{'id': '4bf58dd8d48988d176941735', 'name': 'G...  v-1628518856    False
# 3  [{'id': '4bf58dd8d48988d175941735', 'name': 'G...  v-1628518856    False
# 4  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1628518856    False
#
#            location.address  location.lat  location.lng  \
# 0           11937 Market St     38.958303    -77.357819
# 1                       NaN     38.959167    -77.359444
# 2          11955 Freedom Dr     38.959099    -77.359886
# 3  2143 Rhode Island Avenue     38.957657    -77.357558
# 4          11951 Freedom Dr     38.958345    -77.355309
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 38.958303, 'lng':...                357
# 1  [{'label': 'display', 'lat': 38.95916748046875...                268
# 2  [{'label': 'display', 'lat': 38.95909881591797...                289
# 3  [{'label': 'display', 'lat': 38.95765681368872...                432
# 4  [{'label': 'display', 'lat': 38.95834532186404...                444
#
#   location.postalCode location.cc location.city location.state  \
# 0               20190          US        Reston             VA
# 1               20190          US        Reston             VA
# 2               20190          US        Reston             VA
# 3               22090          US        Reston           D.C.
# 4               20190          US        Reston             VA
#
#   location.country                       location.formattedAddress  \
# 0    United States             [11937 Market St, Reston, VA 20190]
# 1    United States                              [Reston, VA 20190]
# 2    United States            [11955 Freedom Dr, Reston, VA 20190]
# 3    United States  [2143 Rhode Island Avenue, Reston, D.C. 22090]
# 4    United States            [11951 Freedom Dr, Reston, VA 20190]
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2                  NaN          NaN
# 3                  NaN          NaN
# 4                  NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                    name  \
# 0                               The Gym
# 1                       One Freedom Gym
# 2                                L3 Gym
# 3                        The Gym Guides
# 4                             Gym 11951
# 5               One Fountain Square Gym
# 6                               RTC Gym
# 7                     College Board Gym
# 8                           Freedom Gym
# 9                       Parc Reston Gym
# 10                        Archstone Gym
# 11                 Hyatt Regency Reston
# 12  Crunch Fitness - Reston Town Center
# 13                         The Harrison
# 14              Verisign Fitness Center
#
#                                   categories                   address  \
# 0                                        Gym           11937 Market St
# 1                                        Gym                       NaN
# 2                                        Gym          11955 Freedom Dr
# 3                       Gym / Fitness Center  2143 Rhode Island Avenue
# 4                                     Office          11951 Freedom Dr
# 5                                        Gym          11911 Freedom Dr
# 6                       Gym / Fitness Center          11911 Freedom Dr
# 7                                        Gym        11955 Democracy Dr
# 8                                        Gym                       NaN
# 9                                        Gym                       NaN
# 10                        Athletics & Sports                       NaN
# 11                                     Hotel        1800 Presidents St
# 12                      Gym / Fitness Center          11951 Freedom Dr
# 13  Residential Building (Apartment / Condo)         1800 Jonathan Way
# 14                                       Gym                       NaN
#
#           lat        lng                                     labeledLatLngs  \
# 0   38.958303 -77.357819  [{'label': 'display', 'lat': 38.958303, 'lng':...
# 1   38.959167 -77.359444  [{'label': 'display', 'lat': 38.95916748046875...
# 2   38.959099 -77.359886  [{'label': 'display', 'lat': 38.95909881591797...
# 3   38.957657 -77.357558  [{'label': 'display', 'lat': 38.95765681368872...
# 4   38.958345 -77.355309  [{'label': 'display', 'lat': 38.95834532186404...
# 5   38.959364 -77.356116  [{'label': 'display', 'lat': 38.95936384413637...
# 6   38.959106 -77.356178  [{'label': 'display', 'lat': 38.9591064453125,...
# 7   38.958260 -77.359941  [{'label': 'display', 'lat': 38.95825983090204...
# 8   38.958793 -77.356033  [{'label': 'display', 'lat': 38.9587931347436,...
# 9   38.963300 -77.352545  [{'label': 'display', 'lat': 38.96330012185097...
# 10  38.966646 -77.361012  [{'label': 'display', 'lat': 38.96664581743808...
# 11  38.958311 -77.355864  [{'label': 'display', 'lat': 38.95831095377073...
# 12  38.959222 -77.359233  [{'label': 'display', 'lat': 38.95922209991875...
# 13  38.961845 -77.354042  [{'label': 'display', 'lat': 38.96184539819865...
# 14  38.956753 -77.362250  [{'label': 'display', 'lat': 38.95675300000000...
#
#     distance postalCode  cc    city state        country  \
# 0        357      20190  US  Reston    VA  United States
# 1        268      20190  US  Reston    VA  United States
# 2        289      20190  US  Reston    VA  United States
# 3        432      22090  US  Reston  D.C.  United States
# 4        444      20190  US  Reston    VA  United States
# 5        312      20190  US  Reston    VA  United States
# 6        331      20190  US  Reston    VA  United States
# 7        378      20190  US  Reston    VA  United States
# 8        366      20190  US  Reston    VA  United States
# 9        554        NaN  US  Reston    VA  United States
# 10       615      20194  US  Reston    VA  United States
# 11       419      20190  US  Reston    VA  United States
# 12       257      20190  US  Reston    VA  United States
# 13       388      20190  US  Reston    VA  United States
# 14       616      20190  US  Reston    VA  United States
#
#                                      formattedAddress     crossStreet  \
# 0                 [11937 Market St, Reston, VA 20190]             NaN
# 1                                  [Reston, VA 20190]             NaN
# 2                [11955 Freedom Dr, Reston, VA 20190]             NaN
# 3      [2143 Rhode Island Avenue, Reston, D.C. 22090]             NaN
# 4                [11951 Freedom Dr, Reston, VA 20190]             NaN
# 5                [11911 Freedom Dr, Reston, VA 20190]             NaN
# 6                [11911 Freedom Dr, Reston, VA 20190]             NaN
# 7   [11955 Democracy Dr (9th Floor), Reston, VA 20...       9th Floor
# 8                                  [Reston, VA 20190]             NaN
# 9                                        [Reston, VA]             NaN
# 10                                 [Reston, VA 20194]             NaN
# 11             [1800 Presidents St, Reston, VA 20190]             NaN
# 12               [11951 Freedom Dr, Reston, VA 20190]             NaN
# 13  [1800 Jonathan Way (Reston Parkway), Reston, V...  Reston Parkway
# 14                                 [Reston, VA 20190]             NaN
#
#                           id
# 0   4d015a079fada35d4aa33c34
# 1   5092ea90e4b054dd33164e1c
# 2   4d9335897ac3a35d6508d125
# 3   5b85528ada5e560039bc3b15
# 4   4fbbbedae4b05f98660d40fb
# 5   4ca771d3f47ea14320be6a21
# 6   4e8b7cbad3e303e9db2bb950
# 7   4d262d8cb3ad60fc30793506
# 8   4fc8af86e4b01d2b698624c3
# 9   52ae37b811d2321247fd0427
# 10  50c7cdeae4b09076e37b9113
# 11  4ac56d0bf964a520ffb120e3
# 12  51cdc1f5498eb301ccefd973
# 13  544ead43498e60f6ee26cff8
# 14  4f05e27b5c5c4a361b035d64

# %%
# add the gyms as green circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='green',
        popup=label,
        fill = True,
        fill_color='green',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_0fbde067236c48169719d8e12b684c68%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0fbde067236c48169719d8e12b684c68%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0fbde067236c48169719d8e12b684c68%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_0fbde067236c48169719d8e12b684c68%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B38.96146845%2C-77.3585048525%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20% ...

# %%
##Centreville

address = 'Centreville, VA'

geolocator = Nominatim(user_agent="va_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Centreville, Virginia are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Centreville, Virginia are 38.84487, -77.43540260778344.

# %%
address = '14200 St Germain Dr, Centreville, VA 20121'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 38.832106 -77.450555

# %%
search_query = 'gym'
radius = 500
print(search_query + ' .... OK!')
# Out:
# gym .... OK!

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6112d28c58b8f2319dcb96ab'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': []}}

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '61115aaa2bc6b6754dc0638a'},
#  'notifications': [{'type': 'notificationTray', 'item': {'unreadCount': 0}}],
#  'response': {'venues': []}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
